# %% [markdown]
# # Test algoritmo
#
# Con questa pagina, voglio creare un report dello stato dell'algoritmo al 17/07/2017 e mostrare il comportamento a seconda della varizione della luminosità del microscopio. Inizzierò mostrando l'immagine ridotta in dimensione (per il passaggio da tiff a jpg). Questa immagine viene poi processata in modo binario con un cutoff in scala di grigi. Da questa immagine poi si può fare il conteggio delle tracce che poi servirà per il calcolo dei ppm di boro nel campione.

# %% [markdown]
# ## Immagine jpg

# %%
import pylib.TrackAn as TA

TA.TPP("img_test/100 XYF00 ZF0.jpg",True)
# Out:
# 900 x 1200 pixels
# data type: float64
# max: 0.78 min: 0.02
# mean: 0.3209
# (111,
#  0,
#  array([ 18,  26,  40,  30,  52,  92, 105,  64,  99,  22,  83,  60,  15,
#          50,  36,  43,  21,  29, 107,  58,  17,  34, 106,  17,  40,  44,
#          62,  69,  97,  76,  39,  81,  28,  48,  85,  44,  32,  93, 108,
#         140,  19,  90, 104,  67, 104,  87,  99, 111,  55, 110,  67,  76,
#          51,  84,  89,  61,  16,  84,  19, 115,  47,  79,  76, 107,  86,
#          68, 109,  15,  76,  92,  37,  96,  31,  35,  53, 110,  98,  46,
#          39,  47,  71,  34, 106, 105,  26,  57,  76,  61,  71,  63,  28,
#          25,  94,  97,  90,  56,  62, 102,  97,  51, 105,  30,  64, 104,
#          42, 112,  44,  15,  57,  30,  15]))

# %%
TA.GetNOfTracks("img_test/100 XYF00 ZF0.jpg")
# Out:
# 111

# %%
TA.GetNOfTracks("img_test/100 XYF01 ZF0.jpg")
# Out:
# 103

# %%
TA.GetNOfTracks("img_test/100 XYF02 ZF0.jpg")
# Out:
# 103

# %%
TA.GetNOfTracks("img_test/100 XYF03 ZF0.jpg")
# Out:
# 91

# %%
TA.GetNOfTracks("img_test/100 XYF04 ZF0.jpg")
# Out:
# 97

# %%
TA.GetNOfTracks("img_test/100 XYF05 ZF0.jpg")
# Out:
# 122

# %%
TA.GetNOfTracks("img_test/100 XYF06 ZF0.jpg")
# Out:
# 92

# %%
TA.GetNOfTracks("img_test/100 XYF39 ZF0.jpg")
# Out:
# 127

# %%
TA.GetNOfTracks("img_test/100 XYF29 ZF0.jpg")
# Out:
# 129

# %%
TA.GetNOfTracks("img_test/100 XYF27 ZF0.jpg")
# Out:
# 89

# %%
TA.GetNOfTracks("img_test/100 XYF22 ZF0.jpg")
# Out:
# 79

# %%
TA.GetNOfTracks("img_test/100 XYF00 ZF0.jpg")
# Out:
# 111

# %%
TA.TPP("img_test/100 XYF01 ZF0.jpg",True)
# Out:
# 900 x 1200 pixels
# data type: float64
# max: 0.78 min: 0.01
# mean: 0.3227
# (103,
#  0,
#  array([ 16,  41, 119,  22,  66,  35,  92,  31,  16,  23,  87,  77, 107,
#          64,  72,  35, 106,  19,  22,  94,  17,  86,  77,  39,  87,  85,
#         105,  62,  32,  80,  89,  24,  31,  58,  65, 120,  32,  90,  36,
#          36,  90,  69,  39,  44, 135,  22,  75,  28,  64,  41,  63,  97,
#          17,  36,  48,  34,  88,  48,  25,  26,  86,  91,  80,  50,  31,
#          18,  95,  89,  47,  61,  69,  69,  35,  80,  66,  47,  28,  97,
#          46,  68,  46,  68,  89,  96,  63,  20,  90,  24,  50,  95,  53,
#          50,  36,  16,  58, 118,  38,  64,  48,  98,  93,  91,  24]))
